# %% [markdown]
# <a href="https://colab.research.google.com/github/soumitra-001/Python_Baisc/blob/main/Lecture/MCA_Python_06Sep26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 0.1
b = 0.2
print((a+b)==0.3)
# Out:
# False

# %%
a = 0.1
b = 0.2
c = abs((a+b)-0.3)
print(c< 1e-9)  # 10^(-9)
print(c)
# Out:
# True
# 5.551115123125783e-17

# %%
import math

print(math.isclose(a+b,0.3))
# Out:
# True

# %%
from decimal import Decimal

a = Decimal('0.1')
b = Decimal('0.2')

print((a+b) == Decimal('0.3'))
# Out:
# True

# %%
c = 0.1 * 3

print(c)
# Out:
# 0.30000000000000004

# %%
print(round(2.3456,2))
# Out:
# 2.35

# %%
a = 2.675
print(a)
# Out:
# 2.675

# %%
print(format(a,'.50f'))

# precision indicator
# 50. No of digit after decimal point
# F fixed floating decimal notation
# Out:
# 2.67499999999999982236431605997495353221893310546875

# %%
a = 0.1
b = 0.2
c = 0.2

print((a+b)==0.3)
print((c+b)==0.4)

print(repr(a+b))
print(repr(c+b))

# repr
# storing 64-bit binary representation
# built-in fuction to show what is actually stored in memory
# (in this case, showing exact floating point representation stored in memory , it is slowing precise internal val)
# Out:
# False
# True
# 0.30000000000000004
# 0.4

# %%
s = 'hi'
print(s)
print(repr(s))
# Out:
# hi
# 'hi'

# %%
a = True
b = False

print(a and b)
print(a or b)
print( not a)
# Out:
# False
# True
# False
