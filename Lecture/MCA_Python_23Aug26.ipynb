# %% [markdown]
# <a href="https://colab.research.google.com/github/soumitra-001/Python_Baisc/blob/main/Lecture/MCA_Python_23Aug26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 3
c = a/b
print(type(a),type(b),type(c))
# Out:
# <class 'int'> <class 'int'> <class 'float'>

# %%
a = 1
print(id(a))

a = a+1
print(id(a))

a = a+1
print(id(a))
# Out:
# 11277928
# 11277960
# 11277992

# %%
x = 10
y = 10
print(id(x),id(y)) #id(x) and id(y) both are referring to the same object.
# Out:
# 11278216 11278216

# %%
type(x)
# if the values of referring are the same then the referring to the same object.
# Out:
# int

# %%
id(x)-id(y)
# Out:
# 0

# %%
a = [10,20,30]
b = [10,20,30]
print(id(a),id(b))
#a and b are different objects , even there values are similar.
# Out:
# 135184382675520 135184382675328

# %%
type(a)
# Out:
# list

# %%
print(a == b) # if values are equal
print(a is b) # if the objects are equal
# Out:
# True
# False

# %%
import ctypes

a = 1
addr = id(a)

val1 = ctypes.cast(addr , ctypes.py_object).value

print("id(a) : ",addr ,"; value at id(a) :", val1)
# Out:
# id(a) :  11277928 ; value at id(a) : 1

# %% [markdown]
# Float

# %%
a = 1.8
print(id(a))

a = a+1
print(id(a))

a = a+1
print(id(a))
# Out:
# 135184385089552
# 135184385087248
# 135184385095280

# %%
x = 10.2
y = float(10.2)

# Corrected variables inside the print statement
print(type(x), type(y))
print(id(x), id(y))
# Out:
# <class 'float'> <class 'float'>
# 135184384385776 135184384382896

# %%
print(a == b) # if values are equal
print(a is b) # if the objects are equal
# Out:
# False
# False

# %%
a1,a2,a3,a4,a5 = 10,20,30,40,50
print(a1,a2,a3,a4,a5)
# Out:
# 10 20 30 40 50

# %%
a6=a7=a8=90
print(a6,a7,a8)
print(id(a6),id(a7),id(a8))
# Out:
# 90 90 90
# 11280776 11280776 11280776

# %%
marks = [95,98,85,93]
type(marks)
# Out:
# list

# %%
a = "hello World"
for i in a: print(i) # looping in a string . Here i is use as a iterator
# Out:
# h
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
import random

print(random.randrange(1,10)) # to generate a no. within the range of 1 to 10
print(random.randrange(1,2)) # check where 2 is inclusive
# Out:
# 8
# 1

# %%
str1 = "Welcome to IIT patna"

key = "IIT"

print(key in str1) # find key in sting
# Out:
# True

# %%
text = "Python is fun to learn"
result = text.split()

print(result)
# Output: ['Python', 'is', 'fun', 'to', 'learn']
# Out:
# ['Python', 'is', 'fun', 'to', 'learn']
